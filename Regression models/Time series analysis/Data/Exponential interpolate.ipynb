# %% [markdown]
# # Importing libraries

# %%
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
df = pd.read_csv('/content/drive/MyDrive/Biogas RMS project/Datasets/Lab dataset/exponential_reactor1_biogas.csv', index_col="day")
df.head()
# Out:
#      TS_actual  VS_actual     PH100   TI100_PV  reactor1
# day
# 0      369.593   338.3879  8.074410  36.000625         0
# 1          NaN        NaN  8.096889  35.664028       100
# 2          NaN        NaN  7.870299  35.768889       120
# 3          NaN        NaN  7.774347  35.843681       100
# 4          NaN        NaN  7.733986  35.853194       100

# %%
df["TS_actual"].plot()
df["VS_actual"].plot()

# %%
df.interpolate(method='polynomial', order=2)["TS_actual"].plot()
